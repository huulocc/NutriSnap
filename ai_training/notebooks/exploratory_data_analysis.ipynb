# %% [markdown]
# # NutriSnap Dataset EDA
#
# This notebook reads reports generated by the Python scripts. Core pipeline logic stays in scripts, not in the notebook.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
REPORTS = ROOT / 'ai_training' / 'outputs' / 'reports'
PLOTS = ROOT / 'ai_training' / 'outputs' / 'plots'
REPORTS, PLOTS

# %% [markdown]
# ## Class Distribution

# %%
path = REPORTS / 'class_distribution.csv'
pd.read_csv(path) if path.exists() else 'Run inspect_dataset.py first.'

# %% [markdown]
# ## Image Sizes And Aspect Ratios

# %%
summary = REPORTS / 'dataset_summary.csv'
df = pd.read_csv(summary) if summary.exists() else pd.DataFrame()
df[['width', 'height', 'aspect_ratio', 'file_size_bytes']].describe() if not df.empty else 'Run inspect_dataset.py first.'

# %% [markdown]
# ## Duplicate And Corrupted Summaries

# %%
for name in ['exact_duplicates.csv', 'cross_class_duplicates.csv', 'corrupted_images.csv', 'split_summary.csv']:
    path = REPORTS / name
    print(name)
    display(pd.read_csv(path).head() if path.exists() else 'Not generated yet')
